# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = '/home/yohai/computer_vision/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Clear previously loaded data.
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.429944
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -1.797150 analytic: -1.797150, relative error: 5.810661e-09
# numerical: -0.641803 analytic: -0.641803, relative error: 2.113945e-08
# numerical: -1.673575 analytic: -1.673575, relative error: 2.936578e-08
# numerical: -2.528917 analytic: -2.528917, relative error: 6.505030e-09
# numerical: -0.495957 analytic: -0.495957, relative error: 1.291069e-07
# numerical: 2.897563 analytic: 2.897563, relative error: 2.212123e-08
# numerical: -3.954575 analytic: -3.954575, relative error: 1.224590e-09
# numerical: 4.295066 analytic: 4.295066, relative error: 1.197740e-08
# numerical: 0.019457 analytic: 0.019456, relative error: 1.197794e-06
# numerical: -2.071514 analytic: -2.071514, relative error: 2.291618e-08
# numerical: 2.608129 analytic: 2.611368, relative error: 6.204603e-04
# numerical: 2.772704 analytic: 2.767812, relative error: 8.829315e-04
# numerical: 0.381880 analytic: 0.382121, relative error: 3.145076e-04
# numerical: 3.398345 analytic: 3.395846, relative error: 3.678420e-04
# numerical: 3.464406 analytic: 3.461162, relative error: 4.684811e-04
# numerical: -0.211410 analytic: -0.208997, relative error: 5.739994e-03
# numerical: -3.849846 analytic: -3.846026, relative error: 4.964002e-04
# numerical: 0.071899 analytic: 0.065361, relative error: 4.763382e-02
# numerical: -1.126895 analytic: -1.123022, relative error: 1.721352e-03
# numerical: 0.956978 analytic: 0.953740, relative error: 1.694496e-03

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.429944e+00 computed in 0.155358s
# vectorized loss: 2.429944e+00 computed in 0.004543s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [3.3e4, 3.7e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
k = 0
# for l_rate in np.linspace(learning_rates[0], learning_rates[1], 10):
l_rate = (2+1/3.0)*1e-7
for r_strength in np.linspace(regularization_strengths[0], regularization_strengths[1], 20):
    soft_max = Softmax()
    loss_hist = soft_max.train(X_train, y_train, learning_rate=l_rate, reg=r_strength,
                  num_iters=1000, batch_size=500, verbose=True)
    y_train_pred = soft_max.predict(X_train)
    train_acuracy = np.mean(y_train == y_train_pred)
    y_val_pred = soft_max.predict(X_val)
    val_acuracy =  np.mean(y_val == y_val_pred)
    if val_acuracy > best_val:
        best_val = val_acuracy
        best_softmax = soft_max
    results[(l_rate, r_strength)] = (train_acuracy, val_acuracy)
    print(k, (l_rate, r_strength))
    k += 1
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1000: loss 1025.095262
# iteration 100 / 1000: loss 218.374771
# iteration 200 / 1000: loss 48.017372
# iteration 300 / 1000: loss 11.887574
# iteration 400 / 1000: loss 4.225515
# iteration 500 / 1000: loss 2.562340
# iteration 600 / 1000: loss 2.196098
# iteration 700 / 1000: loss 2.165795
# iteration 800 / 1000: loss 2.150977
# iteration 900 / 1000: loss 2.140747
# 0 (2.3333333333333333e-07, 33000.0)
# iteration 0 / 1000: loss 1023.767478
# iteration 100 / 1000: loss 216.211719
# iteration 200 / 1000: loss 47.040901
# iteration 300 / 1000: loss 11.579539
# iteration 400 / 1000: loss 4.103417
# iteration 500 / 1000: loss 2.513955
# iteration 600 / 1000: loss 2.243616
# iteration 700 / 1000: loss 2.149754
# iteration 800 / 1000: loss 2.158337
# iteration 900 / 1000: loss 2.136329
# 1 (2.3333333333333333e-07, 33210.52631578947)
# iteration 0 / 1000: loss 1030.637404
# iteration 100 / 1000: loss 215.374850
# iteration 200 / 1000: loss 46.381077
# iteration 300 / 1000: loss 11.404994
# iteration 400 / 1000: loss 4.012917
# iteration 500 / 1000: loss 2.509740
# iteration 600 / 1000: loss 2.211143
# iteration 700 / 1000: loss 2.116322
# iteration 800 / 1000: loss 2.129001
# iteration 900 / 1000: loss 2.133881
# 2 (2.3333333333333333e-07, 33421.05263157895)
# iteration 0 / 1000: loss 1048.162053
# iteration 100 / 1000: loss 217.145705
# iteration 200 / 1000: loss 46.380204
# iteration 300 / 1000: loss 11.253887
# iteration 400 / 1000: loss 4.036347
# iteration 500 / 1000: loss 2.511197
# iteration 600 / 1000: loss 2.205824
# iteration 700 / 1000: loss 2.146884
# iteration 800 / 1000: loss 2.137639
# iteration 900 / 1000: loss 2.152000
# 3 (2.3333333333333333e-07, 33631.57894736842)
# iteration 0 / 1000: loss 1040.281015
# iteration 100 / 1000: loss 213.230614
# iteration 200 / 1000: loss 45.128378
# iteration 300 / 1000: loss 10.902619
# iteration 400 / 1000: loss 3.907110
# iteration 500 / 1000: loss 2.489304
# iteration 600 / 1000: loss 2.238952
# iteration 700 / 1000: loss 2.165961
# iteration 800 / 1000: loss 2.185112
# iteration 900 / 1000: loss 2.133391
# 4 (2.3333333333333333e-07, 33842.10526315789)
# iteration 0 / 1000: loss 1061.898755
# iteration 100 / 1000: loss 215.445429
# iteration 200 / 1000: loss 45.108761
# iteration 300 / 1000: loss 10.787137
# iteration 400 / 1000: loss 3.903815
# iteration 500 / 1000: loss 2.481409
# iteration 600 / 1000: loss 2.235586
# iteration 700 / 1000: loss 2.124275
# iteration 800 / 1000: loss 2.160655
# iteration 900 / 1000: loss 2.129519
# 5 (2.3333333333333333e-07, 34052.63157894737)
# iteration 0 / 1000: loss 1055.459918
# iteration 100 / 1000: loss 212.193758
# iteration 200 / 1000: loss 44.100778
# iteration 300 / 1000: loss 10.539818
# iteration 400 / 1000: loss 3.787253
# iteration 500 / 1000: loss 2.501619
# iteration 600 / 1000: loss 2.234094
# iteration 700 / 1000: loss 2.123022
# iteration 800 / 1000: loss 2.138953
# iteration 900 / 1000: loss 2.143130
# 6 (2.3333333333333333e-07, 34263.15789473684)
# iteration 0 / 1000: loss 1062.534475
# iteration 100 / 1000: loss 211.346725
# iteration 200 / 1000: loss 43.522238
# iteration 300 / 1000: loss 10.338694
# iteration 400 / 1000: loss 3.726678
# iteration 500 / 1000: loss 2.466642
# iteration 600 / 1000: loss 2.198601
# iteration 700 / 1000: loss 2.158528
# iteration 800 / 1000: loss 2.113376
# iteration 900 / 1000: loss 2.159747
# 7 (2.3333333333333333e-07, 34473.68421052631)
# iteration 0 / 1000: loss 1068.874653
# iteration 100 / 1000: loss 210.382798
# iteration 200 / 1000: loss 42.848250
# iteration 300 / 1000: loss 10.123184
# iteration 400 / 1000: loss 3.734307
# iteration 500 / 1000: loss 2.456813
# iteration 600 / 1000: loss 2.176546
# iteration 700 / 1000: loss 2.141565
# iteration 800 / 1000: loss 2.115906
# iteration 900 / 1000: loss 2.135709
# 8 (2.3333333333333333e-07, 34684.21052631579)
# iteration 0 / 1000: loss 1080.694169
# iteration 100 / 1000: loss 211.054103
# iteration 200 / 1000: loss 42.674787
# iteration 300 / 1000: loss 9.977779
# iteration 400 / 1000: loss 3.665291
# iteration 500 / 1000: loss 2.437283
# iteration 600 / 1000: loss 2.191146
# iteration 700 / 1000: loss 2.117720
# iteration 800 / 1000: loss 2.176331
# iteration 900 / 1000: loss 2.139027
# 9 (2.3333333333333333e-07, 34894.73684210526)
# iteration 0 / 1000: loss 1076.661309
# iteration 100 / 1000: loss 207.891401
# iteration 200 / 1000: loss 41.664640
# iteration 300 / 1000: loss 9.728507
# iteration 400 / 1000: loss 3.630113
# iteration 500 / 1000: loss 2.393811
# iteration 600 / 1000: loss 2.186451
# iteration 700 / 1000: loss 2.177477
# iteration 800 / 1000: loss 2.147541
# iteration 900 / 1000: loss 2.098164
# 10 (2.3333333333333333e-07, 35105.26315789473)
# iteration 0 / 1000: loss 1082.267090
# iteration 100 / 1000: loss 207.196647
# iteration 200 / 1000: loss 41.114702
# iteration 300 / 1000: loss 9.583646
# iteration 400 / 1000: loss 3.573629
# iteration 500 / 1000: loss 2.400174
# iteration 600 / 1000: loss 2.168989
# iteration 700 / 1000: loss 2.152709
# iteration 800 / 1000: loss 2.140260
# iteration 900 / 1000: loss 2.136630
# 11 (2.3333333333333333e-07, 35315.78947368421)
# iteration 0 / 1000: loss 1091.513002
# iteration 100 / 1000: loss 206.601588
# iteration 200 / 1000: loss 40.589270
# iteration 300 / 1000: loss 9.423113
# iteration 400 / 1000: loss 3.520552
# iteration 500 / 1000: loss 2.340410
# iteration 600 / 1000: loss 2.232909
# iteration 700 / 1000: loss 2.138240
# iteration 800 / 1000: loss 2.125636
# iteration 900 / 1000: loss 2.151949
# 12 (2.3333333333333333e-07, 35526.31578947369)
# iteration 0 / 1000: loss 1098.583392
# iteration 100 / 1000: loss 206.134047
# iteration 200 / 1000: loss 40.201794
# iteration 300 / 1000: loss 9.238290
# iteration 400 / 1000: loss 3.473185
# iteration 500 / 1000: loss 2.381654
# iteration 600 / 1000: loss 2.149445
# iteration 700 / 1000: loss 2.164924
# iteration 800 / 1000: loss 2.127369
# iteration 900 / 1000: loss 2.142751
# 13 (2.3333333333333333e-07, 35736.84210526316)
# iteration 0 / 1000: loss 1110.991862
# iteration 100 / 1000: loss 206.386186
# iteration 200 / 1000: loss 39.835538
# iteration 300 / 1000: loss 9.117969
# iteration 400 / 1000: loss 3.410374
# iteration 500 / 1000: loss 2.389246
# iteration 600 / 1000: loss 2.189737
# iteration 700 / 1000: loss 2.201519
# iteration 800 / 1000: loss 2.172045
# iteration 900 / 1000: loss 2.146503
# 14 (2.3333333333333333e-07, 35947.36842105263)
# iteration 0 / 1000: loss 1099.461239
# iteration 100 / 1000: loss 202.258652
# iteration 200 / 1000: loss 38.666734
# iteration 300 / 1000: loss 8.788666
# iteration 400 / 1000: loss 3.361160
# iteration 500 / 1000: loss 2.395011
# iteration 600 / 1000: loss 2.185430
# iteration 700 / 1000: loss 2.154954
# iteration 800 / 1000: loss 2.128852
# iteration 900 / 1000: loss 2.091969
# 15 (2.3333333333333333e-07, 36157.89473684211)
# iteration 0 / 1000: loss 1129.350297
# iteration 100 / 1000: loss 205.413112
# iteration 200 / 1000: loss 38.937567
# iteration 300 / 1000: loss 8.795277
# iteration 400 / 1000: loss 3.347595
# iteration 500 / 1000: loss 2.389277
# iteration 600 / 1000: loss 2.183455
# iteration 700 / 1000: loss 2.095816
# iteration 800 / 1000: loss 2.143768
# iteration 900 / 1000: loss 2.117413
# 16 (2.3333333333333333e-07, 36368.42105263158)
# iteration 0 / 1000: loss 1112.993600
# iteration 100 / 1000: loss 200.747441
# iteration 200 / 1000: loss 37.694046
# iteration 300 / 1000: loss 8.486223
# iteration 400 / 1000: loss 3.319262
# iteration 500 / 1000: loss 2.340252
# iteration 600 / 1000: loss 2.161970
# iteration 700 / 1000: loss 2.177390
# iteration 800 / 1000: loss 2.133352
# iteration 900 / 1000: loss 2.073416
# 17 (2.3333333333333333e-07, 36578.94736842105)
# iteration 0 / 1000: loss 1141.643315
# iteration 100 / 1000: loss 203.903120
# iteration 200 / 1000: loss 37.956600
# iteration 300 / 1000: loss 8.452994
# iteration 400 / 1000: loss 3.265186
# iteration 500 / 1000: loss 2.322899
# iteration 600 / 1000: loss 2.157513
# iteration 700 / 1000: loss 2.215082
# iteration 800 / 1000: loss 2.138698
# iteration 900 / 1000: loss 2.129929
# 18 (2.3333333333333333e-07, 36789.47368421053)
# iteration 0 / 1000: loss 1124.718230
# iteration 100 / 1000: loss 198.821820
# iteration 200 / 1000: loss 36.690401
# iteration 300 / 1000: loss 8.250153
# iteration 400 / 1000: loss 3.212774
# iteration 500 / 1000: loss 2.297100
# iteration 600 / 1000: loss 2.185306
# iteration 700 / 1000: loss 2.124445
# iteration 800 / 1000: loss 2.183682
# iteration 900 / 1000: loss 2.191891
# 19 (2.3333333333333333e-07, 37000.0)
# lr 2.333333e-07 reg 3.300000e+04 train accuracy: 0.342204 val accuracy: 0.359000
# lr 2.333333e-07 reg 3.321053e+04 train accuracy: 0.344143 val accuracy: 0.360000
# lr 2.333333e-07 reg 3.342105e+04 train accuracy: 0.342184 val accuracy: 0.361000
# lr 2.333333e-07 reg 3.363158e+04 train accuracy: 0.342306 val accuracy: 0.354000
# lr 2.333333e-07 reg 3.384211e+04 train accuracy: 0.342102 val accuracy: 0.357000
# lr 2.333333e-07 reg 3.405263e+04 train accuracy: 0.340449 val accuracy: 0.356000
# lr 2.333333e-07 reg 3.426316e+04 train accuracy: 0.338061 val accuracy: 0.353000
# lr 2.333333e-07 reg 3.447368e+04 train accuracy: 0.339000 val accuracy: 0.350000
# lr 2.333333e-07 reg 3.468421e+04 train accuracy: 0.338612 val accuracy: 0.356000
# lr 2.333333e-07 reg 3.489474e+04 train accuracy: 0.345061 val accuracy: 0.352000
# lr 2.333333e-07 reg 3.510526e+04 train accuracy: 0.340612 val accuracy: 0.351000
# lr 2.333333e-07 reg 3.531579e+04 train accuracy: 0.342857 val accuracy: 0.356000
# lr 2.333333e-07 reg 3.552632e+04 train accuracy: 0.342469 val accuracy: 0.354000
# lr 2.333333e-07 reg 3.573684e+04 train accuracy: 0.337816 val accuracy: 0.348000
# lr 2.333333e-07 reg 3.594737e+04 train accuracy: 0.342020 val accuracy: 0.345000
# lr 2.333333e-07 reg 3.615789e+04 train accuracy: 0.339265 val accuracy: 0.357000
# lr 2.333333e-07 reg 3.636842e+04 train accuracy: 0.336857 val accuracy: 0.351000
# lr 2.333333e-07 reg 3.657895e+04 train accuracy: 0.339531 val accuracy: 0.357000
# lr 2.333333e-07 reg 3.678947e+04 train accuracy: 0.343061 val accuracy: 0.339000
# lr 2.333333e-07 reg 3.700000e+04 train accuracy: 0.336633 val accuracy: 0.350000
# best validation accuracy achieved during cross-validation: 0.361000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.354000

# %% [markdown]
# **Inline Question** - *True or False*
#
# It's possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# *Your answer*:
#
# *Your explanation*:

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
